# %%
import pandas as pd
import numpy as np
import json
data = pd.read_csv("C:/Users/USUARIO/Desktop/UANL/7° SEMESTRE/MINERIA DE DATOS/documento1.csv")

# %% [markdown]
# Importar las librerias y abrir el documento de extensión de .csv

# %%
data.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# 2                   11000  200074175         275868.0
# 3                   27000  448130642        1144337.0
# 4                     640   73058679         212204.0
#
#    Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 0                     4834.0                   NaN                  3054
# 1                    48350.0                   NaN                  1238
# 2                    11700.0                   1.0                   994
# 3                   106759.0                   NaN                  2701
# 4                     1873.0                   1.0                   738
#
#       budget  title_year  ACTOR_2_facebook_likes  imdb_score  title_year.1
# 0  237000000        2009                   936.0         7.9        2009.0
# 1  300000000        2007                  5000.0         7.1           NaN
# 2  245000000        2015                   393.0         6.8        2015.0
# 3  250000000        2012                 23000.0         8.5           NaN
# 4  263700000        2012                   632.0         6.6           NaN

# %% [markdown]
# Con Head vemos desde donde empieza

# %%
data.tail()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 9      153.0                     282                   10000
# 10     183.0                     NaN                    2000
# 11     169.0                     NaN                     903
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 9                    25000  301956980         321795.0
# 10                   15000  330249062              NaN
# 11                   18000  200069408         240396.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
#     Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 9                     58753.0                   3.0                   973
# 10                    24450.0                   NaN                  3018
# 11                        NaN                   2.0                  2367
# 12                     2023.0                   1.0                  1243
# 13                    48486.0                   2.0                  1832
#
#        budget  title_year  ACTOR_2_facebook_likes  imdb_score  title_year.1
# 9   250000000        2009                 11000.0         7.5           NaN
# 10  250000000        2016                     NaN         6.9        2016.0
# 11  209000000        2006                 10000.0         6.1           NaN
# 12  200000000        2008                   412.0         6.7        2008.0
# 13  225000000        2006                  5000.0         7.3        2008.0

# %% [markdown]
# Con tail vemos hasta donde termina

# %%
data
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0      178.0                      10                     855
# 1        NaN                     563                    1000
# 2      148.0                      20                     161
# 3        NaN                   22000                   23000
# 4      132.0                   "475"                     530
# 5      156.0                      23                    4000
# 6        NaN                      15                     284
# 7      141.0                      10                   19000
# 8      141.0                      10                   19000
# 9      153.0                     282                   10000
# 10     183.0                     NaN                    2000
# 11     169.0                     NaN                     903
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                     1000  760505847         886204.0
# 1                    40000  309404152         471220.0
# 2                    11000  200074175         275868.0
# 3                    27000  448130642        1144337.0
# 4                      640   73058679         212204.0
# 5                    24000  336530303         383056.0
# 6                      799  200807262         294810.0
# 7                    26000  458991599         462669.0
# 8                    26000  458991599         462669.0
# 9                    25000  301956980         321795.0
# 10                   15000  330249062              NaN
# 11                   18000  200069408         240396.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
#     Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 0                      4834.0                   NaN                  3054
# 1                     48350.0                   NaN                  1238
# 2                     11700.0                   1.0                   994
# 3                    106759.0                   NaN                  2701
# 4                      1873.0                   1.0                   738
# 5                     46055.0                   NaN                  1902
# 6                         NaN                   1.0                   387
# 7                     92000.0                   4.0                  1117
# 8                     92000.0                   4.0                  1117
# 9                     58753.0                   3.0                   973
# 10                    24450.0                   NaN                  3018
# 11                        NaN                   2.0                  2367
# 12                     2023.0                   1.0                  1243
# 13                    48486.0                   2.0                  1832
#
#        budget  title_year  ACTOR_2_facebook_likes  imdb_score  title_year.1
# 0   237000000        2009                   936.0         7.9        2009.0
# 1   300000000        2007                  5000.0         7.1           NaN
# 2   245000000        2015                   393.0         6.8        2015.0
# 3   250000000        2012                 23000.0         8.5           NaN
# 4   263700000        2012                   632.0         6.6           NaN
# 5   258000000        2007                 11000.0         6.2        2007.0
# 6   260000000        2010                   553.0         7.8           NaN
# 7   250000000        2015                 21000.0         7.5           NaN
# 8   250000000        2015                 21000.0         7.5        2015.0
# 9   250000000        2009                 11000.0         7.5           NaN
# 10  250000000        2016                     NaN         6.9        2016.0
# 11  209000000        2006                 10000.0         6.1           NaN
# 12  200000000        2008                   412.0         6.7        2008.0
# 13  225000000        2006                  5000.0         7.3        2008.0

# %% [markdown]
# Visualizamos todos los datos, de igual manera se puede con head(#totaldedatos) o tail(#totaldedatos)

# %%
data.shape
# Out:
# (14, 16)

# %% [markdown]
# Se vizualiza el tamaño de la matriz de la base de datos

# %%
data.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %% [markdown]
# Arroja los nombres de las columnas

# %%
df=data.drop(['num_critic_for_reviews', 'DIRECTOR_facebook_likes', 'actor_3_facebook_likes', 'ACTOR_1_facebook_likes', 'num_voted_users',
       'Cast_Total_facebook_likes', 'facenumber_in_poster', 'num_user_for_reviews', 'ACTOR_2_facebook_likes', 'title_year.1'],axis = 1)
df
# Out:
#                                      movie_title  duration      gross  \
# 0                                       Avatar?ÿ     178.0  760505847
# 1     Pirates of the Caribbean: At World's End?ÿ       NaN  309404152
# 2                                      Spectre?ÿ     148.0  200074175
# 3                        The Dark Knight Rises?ÿ       NaN  448130642
# 4                                  John Carter?ÿ     132.0   73058679
# 5                                 Spider-Man 3?ÿ     156.0  336530303
# 6                                      Tangled?ÿ       NaN  200807262
# 7                      Avengers: Age of Ultron?ÿ     141.0  458991599
# 8                      Avengers: Age of Ultron?ÿ     141.0  458991599
# 9       Harry Potter and the Half-Blood Prince?ÿ     153.0  301956980
# 10          Batman v Superman: Dawn of Justice?ÿ     183.0  330249062
# 11                            Superman Returns?ÿ     169.0  200069408
# 12                           Quantum of Solace?ÿ     106.0  168368427
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ     151.0  423032628
#
#        budget  title_year  imdb_score
# 0   237000000        2009         7.9
# 1   300000000        2007         7.1
# 2   245000000        2015         6.8
# 3   250000000        2012         8.5
# 4   263700000        2012         6.6
# 5   258000000        2007         6.2
# 6   260000000        2010         7.8
# 7   250000000        2015         7.5
# 8   250000000        2015         7.5
# 9   250000000        2009         7.5
# 10  250000000        2016         6.9
# 11  209000000        2006         6.1
# 12  200000000        2008         6.7
# 13  225000000        2006         7.3

# %% [markdown]
# Elimina columnas

# %%
data_frame=df.rename(columns = {'movie_title':'Title', 'duration':'Duration', 'gross':'Gross', 'budget':'Budget', 'title_year':'Year','imdb_score':'IMDB_Score'})
data_frame
# Out:
#                                            Title  Duration      Gross  \
# 0                                       Avatar?ÿ     178.0  760505847
# 1     Pirates of the Caribbean: At World's End?ÿ       NaN  309404152
# 2                                      Spectre?ÿ     148.0  200074175
# 3                        The Dark Knight Rises?ÿ       NaN  448130642
# 4                                  John Carter?ÿ     132.0   73058679
# 5                                 Spider-Man 3?ÿ     156.0  336530303
# 6                                      Tangled?ÿ       NaN  200807262
# 7                      Avengers: Age of Ultron?ÿ     141.0  458991599
# 8                      Avengers: Age of Ultron?ÿ     141.0  458991599
# 9       Harry Potter and the Half-Blood Prince?ÿ     153.0  301956980
# 10          Batman v Superman: Dawn of Justice?ÿ     183.0  330249062
# 11                            Superman Returns?ÿ     169.0  200069408
# 12                           Quantum of Solace?ÿ     106.0  168368427
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ     151.0  423032628
#
#        Budget  Year  IMDB_Score
# 0   237000000  2009         7.9
# 1   300000000  2007         7.1
# 2   245000000  2015         6.8
# 3   250000000  2012         8.5
# 4   263700000  2012         6.6
# 5   258000000  2007         6.2
# 6   260000000  2010         7.8
# 7   250000000  2015         7.5
# 8   250000000  2015         7.5
# 9   250000000  2009         7.5
# 10  250000000  2016         6.9
# 11  209000000  2006         6.1
# 12  200000000  2008         6.7
# 13  225000000  2006         7.3

# %% [markdown]
# Renombramos columnas

# %%
data_frame.dtypes
# Out:
# Title          object
# Duration      float64
# Gross           int64
# Budget          int64
# Year            int64
# IMDB_Score    float64
# dtype: object

# %% [markdown]
# Visualizamos el tipo de datos

# %%
data_frame.isnull()
# Out:
#     Title  Duration  Gross  Budget   Year  IMDB_Score
# 0   False     False  False   False  False       False
# 1   False      True  False   False  False       False
# 2   False     False  False   False  False       False
# 3   False      True  False   False  False       False
# 4   False     False  False   False  False       False
# 5   False     False  False   False  False       False
# 6   False      True  False   False  False       False
# 7   False     False  False   False  False       False
# 8   False     False  False   False  False       False
# 9   False     False  False   False  False       False
# 10  False     False  False   False  False       False
# 11  False     False  False   False  False       False
# 12  False     False  False   False  False       False
# 13  False     False  False   False  False       False

# %% [markdown]
# Nos arroja si hay valores faltantes(True)

# %%
data_frame.isnull().any()
# Out:
# Title         False
# Duration       True
# Gross         False
# Budget        False
# Year          False
# IMDB_Score    False
# dtype: bool

# %% [markdown]
# Nos muestra las columnas con valores nulos

# %%
data_frame.isnull().sum()
# Out:
# Title         0
# Duration      3
# Gross         0
# Budget        0
# Year          0
# IMDB_Score    0
# dtype: int64

# %% [markdown]
# Arroja cuantos valores nulos hay por columna

# %%
data_frame.IMDB_Score.unique()
# Out:
# array([7.9, 7.1, 6.8, 8.5, 6.6, 6.2, 7.8, 7.5, 6.9, 6.1, 6.7, 7.3])

# %%
clase_1 = data_frame[data_frame['IMDB_Score']==6]
clase_1.to_csv('Solo_clase1.csv', index=False)
clase_2 = data_frame[data_frame['IMDB_Score']==7]
clase_2.to_csv('Solo_clase2.csv', index=False)
clase_3 = data_frame[data_frame['IMDB_Score']==8]
clase_3.to_csv('Solo_clase3.csv', index=False)

# %% [markdown]
# Se realizan agrupaciones de los datos

# %%
movies = data_frame.fillna(0)
movies
# Out:
#                                            Title  Duration      Gross  \
# 0                                       Avatar?ÿ     178.0  760505847
# 1     Pirates of the Caribbean: At World's End?ÿ       0.0  309404152
# 2                                      Spectre?ÿ     148.0  200074175
# 3                        The Dark Knight Rises?ÿ       0.0  448130642
# 4                                  John Carter?ÿ     132.0   73058679
# 5                                 Spider-Man 3?ÿ     156.0  336530303
# 6                                      Tangled?ÿ       0.0  200807262
# 7                      Avengers: Age of Ultron?ÿ     141.0  458991599
# 8                      Avengers: Age of Ultron?ÿ     141.0  458991599
# 9       Harry Potter and the Half-Blood Prince?ÿ     153.0  301956980
# 10          Batman v Superman: Dawn of Justice?ÿ     183.0  330249062
# 11                            Superman Returns?ÿ     169.0  200069408
# 12                           Quantum of Solace?ÿ     106.0  168368427
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ     151.0  423032628
#
#        Budget  Year  IMDB_Score
# 0   237000000  2009         7.9
# 1   300000000  2007         7.1
# 2   245000000  2015         6.8
# 3   250000000  2012         8.5
# 4   263700000  2012         6.6
# 5   258000000  2007         6.2
# 6   260000000  2010         7.8
# 7   250000000  2015         7.5
# 8   250000000  2015         7.5
# 9   250000000  2009         7.5
# 10  250000000  2016         6.9
# 11  209000000  2006         6.1
# 12  200000000  2008         6.7
# 13  225000000  2006         7.3

# %% [markdown]
# Visualizamos la base de datos sin los valores nulos

# %%
movies.Duration.astype("int")
# Out:
# 0     178
# 1       0
# 2     148
# 3       0
# 4     132
# 5     156
# 6       0
# 7     141
# 8     141
# 9     153
# 10    183
# 11    169
# 12    106
# 13    151
# Name: Duration, dtype: int32

# %% [markdown]
# Cambia valores flotantes por enteros

# %%
movies.shape
# Out:
# (14, 6)

# %%
movies.dtypes
# Out:
# Title          object
# Duration      float64
# Gross           int64
# Budget          int64
# Year            int64
# IMDB_Score    float64
# dtype: object

# %%
movies
# Out:
#                                            Title  Duration      Gross  \
# 0                                       Avatar?ÿ     178.0  760505847
# 1     Pirates of the Caribbean: At World's End?ÿ       0.0  309404152
# 2                                      Spectre?ÿ     148.0  200074175
# 3                        The Dark Knight Rises?ÿ       0.0  448130642
# 4                                  John Carter?ÿ     132.0   73058679
# 5                                 Spider-Man 3?ÿ     156.0  336530303
# 6                                      Tangled?ÿ       0.0  200807262
# 7                      Avengers: Age of Ultron?ÿ     141.0  458991599
# 8                      Avengers: Age of Ultron?ÿ     141.0  458991599
# 9       Harry Potter and the Half-Blood Prince?ÿ     153.0  301956980
# 10          Batman v Superman: Dawn of Justice?ÿ     183.0  330249062
# 11                            Superman Returns?ÿ     169.0  200069408
# 12                           Quantum of Solace?ÿ     106.0  168368427
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ     151.0  423032628
#
#        Budget  Year  IMDB_Score
# 0   237000000  2009         7.9
# 1   300000000  2007         7.1
# 2   245000000  2015         6.8
# 3   250000000  2012         8.5
# 4   263700000  2012         6.6
# 5   258000000  2007         6.2
# 6   260000000  2010         7.8
# 7   250000000  2015         7.5
# 8   250000000  2015         7.5
# 9   250000000  2009         7.5
# 10  250000000  2016         6.9
# 11  209000000  2006         6.1
# 12  200000000  2008         6.7
# 13  225000000  2006         7.3

# %% [markdown]
# # DATOS
# ## VISUALIZACIÓN DE LA BASE DE DATOS
# Utilizando head y tail obtenemos el total de datos que estamos manejando, para visualizar completa nuestra base de datos colocamos el numero total de filas en el parentesis del head o del tail.
# Observamos que estamos manejando una matriz de 14 x 16, siendo 14 las filas y 16 las columnas.
#
# ## FILTRAR INFORMACIÓN
# Eliminamos las columnas del año 1, los likes de facebook asi como la cantidad de reviews de parte de los criticos y usuarios. Queremos informacion mas concreta.
#
# ## TIPOS DE VARIABLES
#     Title          object
#     Duration      float64
#     Gross           int64
#     Budget          int64
#     Year            int64
#     IMDB_Score    float64
#
#    ## ELIMINAR VALORES NULOS
#   En el caso de las columnas con valores nulos se colocaron ceros, ya que esos datos se evaluaran como enteros o flotantes, según sea el caso.
#
#    ## PREGUNTAS DE INTERES
#      1.- ¿Para qué me puede servir estas agrupaciones en la práctica siguiente?
#     Para tener rangos de clases lo cual facilita la evaluacion de los datos, puede ser por ejemplo la cantidad de likes que de  de 10 a 20 likes etc.
#      2.- Importancia del analisis previo de los datos antes de iniciar las modificaciones.
#     Sirve para tener una idea más clara de los datos con los que estamos, así mismo tomamos mejores decisiones al momento de filtrar y al evaluar la información tenemos una idea más acertada de que es lo que necesitamos o queremos hacer con ella.
#      3.- Investigar los siguientes comandos:
#      - df.dropna(): Regresa el objeto con etiquetas en los ejes donde falta de manera aleatoria algún dato.
#                     DataFrame.dropna(self, axis=0, how='any', thresh=None, subset=None, inplace=False)
#      - df.astype(): Emite un objeto de panda a algún tipo de caracter especifico
#                     DataFrame.astype(self: ~FrameOrSeries, dtype, copy: bool = True, errors: str = 'raise')
