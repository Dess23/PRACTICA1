# %%
import pandas as pd
import numpy as np
import json
data = pd.read_csv("C:/Users/USUARIO/Desktop/UANL/7° SEMESTRE/MINERIA DE DATOS/documento1.csv")

# %% [markdown]
# Importar las librerias y abrir el documento de extensión de .csv

# %%
data.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# Con Head vemos desde donde empieza

# %%
data.tail()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 9      153.0                     282                   10000
# 10     183.0                     NaN                    2000
# 11     169.0                     NaN                     903
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 9                    25000  301956980         321795.0
# ...

# %% [markdown]
# Con tail vemos hasta donde termina

# %%
data
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# Visualizamos todos los datos, de igual manera se puede con head(#totaldedatos) o tail(#totaldedatos)

# %%
data.shape
# Out:
# (14, 16)

# %% [markdown]
# Se vizualiza el tamaño de la matriz de la base de datos

# %%
data.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %% [markdown]
# Arroja los nombres de las columnas

# %%
df=data.drop(['facenumber_in_poster','title_year','duration','title_year.1','DIRECTOR_facebook_likes','Cast_Total_facebook_likes'],axis = 1)
df
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# Elimina columnas

# %%
data_frame=df.rename(columns = {'movie_title':'Title','num_critic_for_reviews':'Critics_Reviews', 'actor_3_facebook_likes':"Actor_3_fb_likes",
       'ACTOR_1_facebook_likes':'Actor_1_fb_likes', 'gross':'Gross', 'num_voted_users':'Users_Votes', 'budget':'Budget','num_user_for_reviews':'Users_Reviews',
       'ACTOR_2_facebook_likes':'Actor_2_Fb_likes', 'imdb_score':'IMDB_Score'})
data_frame
# Out:
#                                            Title  Critics_Reviews  \
# 0                                       Avatar?ÿ              723
# 1     Pirates of the Caribbean: At World's End?ÿ              302
# 2                                      Spectre?ÿ              602
# 3                        The Dark Knight Rises?ÿ              813
# 4                                  John Carter?ÿ              462
# 5                                 Spider-Man 3?ÿ              392
# 6                                      Tangled?ÿ              324
# 7                      Avengers: Age of Ultron?ÿ              635
# 8                      Avengers: Age of Ultron?ÿ              635
# 9       Harry Potter and the Half-Blood Prince?ÿ              375
# 10          Batman v Superman: Dawn of Justice?ÿ              673
# 11                            Superman Returns?ÿ              434
# 12                           Quantum of Solace?ÿ              403
# ...

# %% [markdown]
# Renombramos columnas

# %%
data_frame.dtypes
# Out:
# Title                object
# Critics_Reviews       int64
# Actor_3_Fb_likes      int64
# Actor_1_Fb_likes      int64
# Gross                 int64
# Users_Votes         float64
# Users_Reviews         int64
# Budget                int64
# Actor_2_Fb_likes    float64
# IMDB_Score          float64
# dtype: object

# %% [markdown]
# Visualizamos el tipo de datos

# %%
data_frame.isnull()
# Out:
#     Title  Critics_Reviews  Actor_3_fb_likes  Actor_1_fb_likes  Gross  \
# 0   False            False             False             False  False
# 1   False            False             False             False  False
# 2   False            False             False             False  False
# 3   False            False             False             False  False
# 4   False            False             False             False  False
# 5   False            False             False             False  False
# 6   False            False             False             False  False
# 7   False            False             False             False  False
# 8   False            False             False             False  False
# 9   False            False             False             False  False
# 10  False            False             False             False  False
# 11  False            False             False             False  False
# ...

# %% [markdown]
# Nos arroja si hay valores faltantes(True)

# %%
data_frame.isnull().any()
# Out:
# Title               False
# Critics_Reviews     False
# Actor_3_Fb_likes    False
# Actor_1_Fb_likes    False
# Gross               False
# Users_Votes          True
# Users_Reviews       False
# Budget              False
# Actor_2_Fb_likes     True
# IMDB_Score          False
# dtype: bool

# %% [markdown]
# Nos muestra las columnas con valores nulos

# %%
data_frame.isnull().sum()
# Out:
# Title               0
# Critics_Reviews     0
# Actor_3_Fb_likes    0
# Actor_1_Fb_likes    0
# Gross               0
# Users_Votes         0
# Users_Reviews       0
# Budget              0
# Actor_2_Fb_likes    0
# IMDB_Score          0
# dtype: int64

# %% [markdown]
# Arroja cuantos valores nulos hay por columna

# %%
data_frame.Users_Votes.unique()
# Out:
# array([ 886204.,  471220.,  275868., 1144337.,  212204.,  383056.,
#         294810.,  462669.,  321795.,      nan,  240396.,  330784.,
#         522040.])

# %%
clase_1 = data_frame[data_frame['IMDB_Score']==6]
clase_1.to_csv('Solo_clase1.csv', index=False)
clase_2 = data_frame[data_frame['IMDB_Score']==7]
clase_2.to_csv('Solo_clase2.csv', index=False)
clase_3 = data_frame[data_frame['IMDB_Score']==8]
clase_3.to_csv('Solo_clase3.csv', index=False)

# %% [markdown]
# Se realizan agrupaciones de los datos

# %%
movies = data_frame.fillna(0)
movies
# Out:
#                                            Title  Critics_Reviews  \
# 0                                       Avatar?ÿ              723
# 1     Pirates of the Caribbean: At World's End?ÿ              302
# 2                                      Spectre?ÿ              602
# 3                        The Dark Knight Rises?ÿ              813
# 4                                  John Carter?ÿ              462
# 5                                 Spider-Man 3?ÿ              392
# 6                                      Tangled?ÿ              324
# 7                      Avengers: Age of Ultron?ÿ              635
# 8                      Avengers: Age of Ultron?ÿ              635
# 9       Harry Potter and the Half-Blood Prince?ÿ              375
# 10          Batman v Superman: Dawn of Justice?ÿ              673
# 11                            Superman Returns?ÿ              434
# 12                           Quantum of Solace?ÿ              403
# ...

# %% [markdown]
# Visualizamos la base de datos sin los valores nulos

# %%
Users_votes=movies.Users_Votes.astype("int")
Users_votes
# Out:
# 0      886204
# 1      471220
# 2      275868
# 3     1144337
# 4      212204
# 5      383056
# 6      294810
# 7      462669
# 8      462669
# 9      321795
# 10          0
# 11     240396
# 12     330784
# 13     522040
# Name: Users_Votes, dtype: int32

# %% [markdown]
# Cambia valores flotantes por enteros

# %%
Actor_2_fb_likes=movies.Actor_2_Fb_likes.astype("int")
Actor_2_fb_likes
# Out:
# 0       936
# 1      5000
# 2       393
# 3     23000
# 4       632
# 5     11000
# 6       553
# 7     21000
# 8     21000
# 9     11000
# 10        0
# 11    10000
# 12      412
# 13     5000
# Name: Actor_2_Fb_likes, dtype: int32

# %% [markdown]
# Cambia valores flotantes por enteros

# %%
movies.shape
# Out:
# (14, 10)

# %%
movies.dtypes
# Out:
# Title                object
# Critics_Reviews       int64
# Actor_3_fb_likes      int64
# Actor_1_fb_likes      int64
# Gross                 int64
# Users_Votes         float64
# Users_Reviews         int64
# Budget                int64
# Actor_2_Fb_likes    float64
# IMDB_Score          float64
# dtype: object

# %%
movies.Title.rstrip("?ÿ")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-4aba2da49695> in <module>
# ----> 1 movies.Title.rstrip("?ÿ")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'rstrip'

# %% [markdown]
# # DATOS
# ## VISUALIZACIÓN DE LA BASE DE DATOS
# Utilizando head y tail obtenemos el total de datos que estamos manejando, para visualizar completa nuestra base de datos colocamos el numero total de filas en el parentesis del head o del tail.
# Observamos que estamos manejando una matriz de 14 x 16, siendo 14 las filas y 16 las columnas.
#
# ## FILTRAR INFORMACIÓN
# Eliminamos las columnas de los años y la duración de las peliculas ya que son variables que no realmente no afectan a las críticas o reseñas de las peliculas, de igual forma quitamos los likes del director y del cast debido a que es más común que las personas se fijen más en un actor o actriz en específico.
#
# ## TIPOS DE VARIABLES
#     -Title                object
#     -Critics_Reviews       int64
#     -Actor_3_Fb_likes      int64
#     -Actor_1_Fb_likes      int64
#     -Gross                 int64
#     -Users_Votes         float64
#     -Users_Reviews         int64
#     -Budget                int64
#     -Actor_2_Fb_likes    float64
#     -IMDB_Score          float64
#
#    ## ELIMINAR VALORES NULOS
#   En el caso de las columnas con valores nulos se colocaron ceros, ya que esos datos se evaluaran como enteros o flotantes, según sea el caso.
#
#    ## PREGUNTAS DE INTERES
#      1.- ¿Para qué me puede servir estas agrupaciones en la práctica siguiente?
#     Para tener rangos de clases lo cual facilita la evaluacion de los datos, puede ser por ejemplo la cantidad de likes que de  de 10 a 20 likes etc.
#      2.- Importancia del analisis previo de los datos antes de iniciar las modificaciones.
#     Sirve para tener una idea más clara de los datos con los que estamos, así mismo tomamos mejores decisiones al momento de filtrar y al evaluar la información tenemos una idea más acertada de que es lo que necesitamos o queremos hacer con ella.
#      3.- Investigar los siguientes comandos:
#      - df.dropna(): Regresa el objeto con etiquetas en los ejes donde falta de manera aleatoria algún dato.
#                     DataFrame.dropna(self, axis=0, how='any', thresh=None, subset=None, inplace=False)
#      - df.astype(): Emite un objeto de panda a algún tipo de caracter especifico
#                     DataFrame.astype(self: ~FrameOrSeries, dtype, copy: bool = True, errors: str = 'raise')
